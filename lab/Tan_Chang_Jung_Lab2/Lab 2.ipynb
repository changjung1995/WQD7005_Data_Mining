# %% [markdown]
# # 1. Prequisite

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('lab1.csv')

# %%
# change DemCluster from interval/integer to nominal/str
df['DemCluster'] = df['DemCluster'].astype(str)
    
# change DemHomeOwner into binary 0/1 variable
dem_home_owner_map = {'U':0, 'H': 1}
df['DemHomeOwner'] = df['DemHomeOwner'].map(dem_home_owner_map)
    
# denote errorneous values in DemMidIncome
mask = df['DemMedIncome'] < 1
df.loc[mask, 'DemMedIncome'] = np.nan
    
# impute missing values in DemAge with its mean
df['DemAge'].fillna(df['DemAge'].mean(), inplace=True)

# impute med income using mean
df['DemMedIncome'].fillna(df['DemMedIncome'].mean(), inplace=True)

# impute gift avg card 36 using mean
df['GiftAvgCard36'].fillna(df['GiftAvgCard36'].mean(), inplace=True)
    
# drop ID and the unused target variable
df.drop(['ID', 'TargetD'], axis=1, inplace=True)
    
# one-hot encoding
df = pd.get_dummies(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9686 entries, 0 to 9685
# Data columns (total 86 columns):
# TargetB             9686 non-null int64
# GiftCnt36           9686 non-null int64
# GiftCntAll          9686 non-null int64
# GiftCntCard36       9686 non-null int64
# GiftCntCardAll      9686 non-null int64
# GiftAvgLast         9686 non-null float64
# GiftAvg36           9686 non-null float64
# GiftAvgAll          9686 non-null float64
# GiftAvgCard36       9686 non-null float64
# GiftTimeLast        9686 non-null int64
# GiftTimeFirst       9686 non-null int64
# PromCnt12           9686 non-null int64
# PromCnt36           9686 non-null int64
# PromCntAll          9686 non-null int64
# PromCntCard12       9686 non-null int64
# PromCntCard36       9686 non-null int64
# PromCntCardAll      9686 non-null int64
# StatusCatStarAll    9686 non-null int64
# DemAge              9686 non-null float64
# DemHomeOwner        9686 non-null int64
# DemMedHomeValue     9686 non-null int64
# DemPctVeterans      9686 non-null int64
# DemMedIncome        9686 non-null float64
# StatusCat96NK_A     9686 non-null uint8
# StatusCat96NK_E     9686 non-null uint8
# StatusCat96NK_F     9686 non-null uint8
# StatusCat96NK_L     9686 non-null uint8
# StatusCat96NK_N     9686 non-null uint8
# StatusCat96NK_S     9686 non-null uint8
# DemCluster_0        9686 non-null uint8
# DemCluster_1        9686 non-null uint8
# DemCluster_10       9686 non-null uint8
# DemCluster_11       9686 non-null uint8
# DemCluster_12       9686 non-null uint8
# DemCluster_13       9686 non-null uint8
# DemCluster_14       9686 non-null uint8
# DemCluster_15       9686 non-null uint8
# DemCluster_16       9686 non-null uint8
# DemCluster_17       9686 non-null uint8
# DemCluster_18       9686 non-null uint8
# DemCluster_19       9686 non-null uint8
# DemCluster_2        9686 non-null uint8
# DemCluster_20       9686 non-null uint8
# DemCluster_21       9686 non-null uint8
# DemCluster_22       9686 non-null uint8
# DemCluster_23       9686 non-null uint8
# DemCluster_24       9686 non-null uint8
# DemCluster_25       9686 non-null uint8
# DemCluster_26       9686 non-null uint8
# DemCluster_27       9686 non-null uint8
# DemCluster_28       9686 non-null uint8
# DemCluster_29       9686 non-null uint8
# DemCluster_3        9686 non-null uint8
# DemCluster_30       9686 non-null uint8
# DemCluster_31       9686 non-null uint8
# DemCluster_32       9686 non-null uint8
# DemCluster_33       9686 non-null uint8
# DemCluster_34       9686 non-null uint8
# DemCluster_35       9686 non-null uint8
# DemCluster_36       9686 non-null uint8
# DemCluster_37       9686 non-null uint8
# DemCluster_38       9686 non-null uint8
# DemCluster_39       9686 non-null uint8
# DemCluster_4        9686 non-null uint8
# DemCluster_40       9686 non-null uint8
# DemCluster_41       9686 non-null uint8
# DemCluster_42       9686 non-null uint8
# DemCluster_43       9686 non-null uint8
# DemCluster_44       9686 non-null uint8
# DemCluster_45       9686 non-null uint8
# DemCluster_46       9686 non-null uint8
# DemCluster_47       9686 non-null uint8
# DemCluster_48       9686 non-null uint8
# DemCluster_49       9686 non-null uint8
# DemCluster_5        9686 non-null uint8
# DemCluster_50       9686 non-null uint8
# DemCluster_51       9686 non-null uint8
# DemCluster_52       9686 non-null uint8
# DemCluster_53       9686 non-null uint8
# DemCluster_6        9686 non-null uint8
# DemCluster_7        9686 non-null uint8
# DemCluster_8        9686 non-null uint8
# DemCluster_9        9686 non-null uint8
# DemGender_F         9686 non-null uint8
# DemGender_M         9686 non-null uint8
# DemGender_U         9686 non-null uint8
# dtypes: float64(6), int64(17), uint8(63)
# memory usage: 2.3 MB

# %% [markdown]
# # 2. Data Partitioning

# %% [markdown]
# # a) Describe training, validation and test dataset.

# %% [markdown]
# # b) What is the purpose for each of these split?

# %% [markdown]
# Training dataset is the dataset that used to train and fit the model.

# %% [markdown]
# Validation dataset used to provide an unbiased evaluation of a model fit on the training dataset while tuning the model hyperparameters.

# %% [markdown]
# Whereas testing dataset used to provide an unbiased evaluation of a final model that trained on the training dataset.

# %% [markdown]
# # c) What is k-fold cross validation?

# %% [markdown]
# K-Fold cross validation is where a given data set is split into a K number of sections/folds where each fold is used as a testing set at some point. If the data set is split into k folds. In the first iteration, the first fold is used to test the model and the rest are used to train the model. In the second iteration, 2nd fold is used as the testing set while the rest serve as the training set. This process is repeated until each fold of the k folds have been used as the testing set.

# %% [markdown]
# # d) What is the advantage and disadvantage of k-fold CV compared to normal training/test/validation method?

# %% [markdown]
# No randomness of using some observations for training versus validation set like in training/test/validation method as each observation is considered for both training and validation. This can reduce the variability of model.

# %% [markdown]
# K-fold doesn’t perform well with time series data.

# %% [markdown]
# # 3. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split

# %%
def important_features(model, feature_names, n_to_display=20):
    # grab feature importances from the model
    importances = model.feature_importances_

    # sort them out in descending order
    indices = np.argsort(importances)
    indices = np.flip(indices, axis=0)

    # limit to 20 features
    indices = indices[:n_to_display]

    for i in indices:
       print(feature_names[i], ':', importances[i])

# %%
def visualize_decision_tree(model, feature_names, save_name):
    import pydot
    from io import StringIO
    from sklearn.tree import export_graphviz

    dotfile = StringIO()
    export_graphviz(model, out_file=dotfile, feature_names=feature_names)
    graph = pydot.graph_from_dot_data(dotfile.getvalue())
    graph[0].write_png(save_name) # saved in the following file

# %%
y = df['TargetB']
X = df.drop(['TargetB'], axis=1)

X_mat = np.asmatrix(X)
X_train, X_test, y_train, y_test = train_test_split(X_mat, y, test_size=0.3, stratify=y, random_state=0)

# %%
model = DecisionTreeClassifier(random_state=0)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=0, splitter='best')

# %%
model.score(X_train, y_train)
# Out:
# 1.0

# %%
model.score(X_test, y_test)
# Out:
# 0.5175498967653132

# %% [markdown]
# The lower accuracy score of testing data indicates the model is overfitting

# %%
important_features(model, X.columns, 20)
# Out:
# DemMedHomeValue : 0.08856216558156052
# DemMedIncome : 0.07429455482500676
# DemPctVeterans : 0.07291816310685263
# DemAge : 0.0701716362678387
# GiftAvgAll : 0.06046906677836176
# GiftTimeFirst : 0.048850667094453015
# GiftTimeLast : 0.04287600684851861
# PromCnt36 : 0.03820770101221019
# GiftAvgCard36 : 0.03374873291216412
# GiftAvg36 : 0.03350964949337565
# GiftCnt36 : 0.032095432655321235
# PromCnt12 : 0.030508011841672542
# PromCntAll : 0.029553356644503426
# GiftAvgLast : 0.02951945886316395
# GiftCntAll : 0.02918192123013657
# PromCntCard36 : 0.028498712459709818
# GiftCntCardAll : 0.027189622906557
# PromCntCardAll : 0.02611013420524961
# PromCntCard12 : 0.01267787275491708
# GiftCntCard36 : 0.011898250866343303

# %% [markdown]
# The first top 5 import features are DemMedHomeValue, DemMedIncome, DemPctVeterans, DemAge and GiftAvgAll.

# %%
import pydot
import graphviz
from io import StringIO
from sklearn.tree import export_graphviz
import os
os.environ["PATH"] += os.pathsep + 'c:/users/tan chang jung/anaconda3/lib/site-packages/graphviz/'

# %%
dotfile = StringIO()
export_graphviz(model, out_file=dotfile, feature_names=X.columns)
graph = pydot.graph_from_dot_data(dotfile.getvalue())

# %%
print(graph[0])
# Out:
# digraph Tree {
# node [shape=box];
# 0 [label="GiftCnt36 <= 2.5\ngini = 0.5\nsamples = 6780\nvalue = [3390, 3390]"];
# 1 [label="DemMedHomeValue <= 67550.0\ngini = 0.489\nsamples = 3118\nvalue = [1788, 1330]"];
# 0 -> 1  [headlabel="True", labelangle=45, labeldistance="2.5"];
# 2 [label="GiftAvgLast <= 14.5\ngini = 0.468\nsamples = 1211\nvalue = [758, 453]"];
# 1 -> 2;
# 3 [label="PromCntCard36 <= 6.5\ngini = 0.5\nsamples = 221\nvalue = [108, 113]"];
# 2 -> 3;
# 4 [label="DemMedHomeValue <= 55350.0\ngini = 0.472\nsamples = 76\nvalue = [47, 29]"];
# 3 -> 4;
# 5 [label="PromCntCardAll <= 10.5\ngini = 0.414\nsamples = 58\nvalue = [41, 17]"];
# 4 -> 5;
# 6 [label="DemAge <= 76.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"];
# 5 -> 6;
# 7 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"];
# 6 -> 7;
# 8 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 6 -> 8;
# 9 [label="DemMedIncome <= 25340.0\ngini = 0.355\nsamples = 52\nvalue = [40, 12]"];
# 5 -> 9;
# 10 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 9 -> 10;
# 11 [label="GiftTimeLast <= 18.5\ngini = 0.32\nsamples = 50\nvalue = [40, 10]"];
# 9 -> 11;
# 12 [label="DemAge <= 83.5\ngini = 0.18\nsamples = 30\nvalue = [27, 3]"];
# 11 -> 12;
# 13 [label="GiftTimeFirst <= 53.5\ngini = 0.071\nsamples = 27\nvalue = [26, 1]"];
# 12 -> 13;
# 14 [label="GiftCntCardAll <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 13 -> 14;
# 15 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 14 -> 15;
# 16 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 14 -> 16;
# 17 [label="gini = 0.0\nsamples = 25\nvalue = [25, 0]"];
# 13 -> 17;
# 18 [label="GiftCnt36 <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"];
# 12 -> 18;
# 19 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 18 -> 19;
# 20 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 18 -> 20;
# 21 [label="GiftTimeFirst <= 100.5\ngini = 0.455\nsamples = 20\nvalue = [13, 7]"];
# 11 -> 21;
# 22 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 21 -> 22;
# 23 [label="GiftAvgAll <= 7.965\ngini = 0.401\nsamples = 18\nvalue = [13, 5]"];
# 21 -> 23;
# 24 [label="PromCntAll <= 69.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]"];
# 23 -> 24;
# 25 [label="GiftTimeFirst <= 117.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]"];
# 24 -> 25;
# 26 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 25 -> 26;
# 27 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 25 -> 27;
# 28 [label="GiftTimeFirst <= 126.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"];
# 24 -> 28;
# 29 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 28 -> 29;
# 30 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 28 -> 30;
# 31 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]"];
# 23 -> 31;
# 32 [label="PromCntCardAll <= 23.5\ngini = 0.444\nsamples = 18\nvalue = [6, 12]"];
# 4 -> 32;
# 33 [label="StatusCat96NK_E <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"];
# 32 -> 33;
# 34 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"];
# 33 -> 34;
# 35 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 33 -> 35;
# 36 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]"];
# 32 -> 36;
# 37 [label="PromCnt12 <= 10.5\ngini = 0.487\nsamples = 145\nvalue = [61, 84]"];
# 3 -> 37;
# 38 [label="GiftTimeFirst <= 129.5\ngini = 0.312\nsamples = 31\nvalue = [6, 25]"];
# 37 -> 38;
# 39 [label="DemCluster_30 <= 0.5\ngini = 0.198\nsamples = 27\nvalue = [3, 24]"];
# 38 -> 39;
# 40 [label="DemCluster_40 <= 0.5\ngini = 0.077\nsamples = 25\nvalue = [1, 24]"];
# 39 -> 40;
# 41 [label="gini = 0.0\nsamples = 23\nvalue = [0, 23]"];
# 40 -> 41;
# 42 [label="GiftTimeLast <= 21.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 40 -> 42;
# 43 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 42 -> 43;
# 44 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 42 -> 44;
# 45 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 39 -> 45;
# 46 [label="PromCnt36 <= 24.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]"];
# 38 -> 46;
# 47 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 46 -> 47;
# 48 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"];
# 46 -> 48;
# 49 [label="PromCntCard36 <= 7.5\ngini = 0.499\nsamples = 114\nvalue = [55, 59]"];
# 37 -> 49;
# 50 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]"];
# 49 -> 50;
# 51 [label="DemAge <= 31.0\ngini = 0.5\nsamples = 108\nvalue = [55, 53]"];
# 49 -> 51;
# 52 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 51 -> 52;
# 53 [label="DemMedIncome <= 30243.0\ngini = 0.5\nsamples = 103\nvalue = [50, 53]"];
# 51 -> 53;
# 54 [label="DemAge <= 42.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]"];
# 53 -> 54;
# 55 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 54 -> 55;
# 56 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]"];
# 54 -> 56;
# 57 [label="DemMedHomeValue <= 39850.0\ngini = 0.496\nsamples = 95\nvalue = [43, 52]"];
# 53 -> 57;
# 58 [label="GiftAvgAll <= 8.03\ngini = 0.397\nsamples = 22\nvalue = [6, 16]"];
# 57 -> 58;
# 59 [label="PromCntCardAll <= 27.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]"];
# 58 -> 59;
# 60 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 59 -> 60;
# 61 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 59 -> 61;
# 62 [label="DemPctVeterans <= 45.5\ngini = 0.133\nsamples = 14\nvalue = [1, 13]"];
# 58 -> 62;
# 63 [label="gini = 0.0\nsamples = 13\nvalue = [0, 13]"];
# 62 -> 63;
# 64 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 62 -> 64;
# 65 [label="GiftAvg36 <= 7.75\ngini = 0.5\nsamples = 73\nvalue = [37, 36]"];
# 57 -> 65;
# 66 [label="PromCnt12 <= 13.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]"];
# 65 -> 66;
# 67 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]"];
# 66 -> 67;
# 68 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"];
# 66 -> 68;
# 69 [label="DemGender_F <= 0.5\ngini = 0.488\nsamples = 59\nvalue = [34, 25]"];
# 65 -> 69;
# 70 [label="PromCnt36 <= 28.5\ngini = 0.49\nsamples = 28\nvalue = [12, 16]"];
# 69 -> 70;
# 71 [label="PromCnt36 <= 23.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]"];
# 70 -> 71;
# 72 [label="DemMedIncome <= 62330.729\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"];
# 71 -> 72;
# 73 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 72 -> 73;
# 74 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 72 -> 74;
# 75 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"];
# 71 -> 75;
# 76 [label="GiftTimeFirst <= 126.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]"];
# 70 -> 76;
# 77 [label="PromCntCard12 <= 5.5\ngini = 0.486\nsamples = 12\nvalue = [5, 7]"];
# 76 -> 77;
# 78 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 77 -> 78;
# 79 [label="DemCluster_8 <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]"];
# 77 -> 79;
# 80 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]"];
# 79 -> 80;
# 81 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 79 -> 81;
# 82 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]"];
# 76 -> 82;
# 83 [label="DemAge <= 65.0\ngini = 0.412\nsamples = 31\nvalue = [22, 9]"];
# 69 -> 83;
# 84 [label="DemCluster_0 <= 0.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]"];
# 83 -> 84;
# 85 [label="gini = 0.0\nsamples = 15\nvalue = [15, 0]"];
# 84 -> 85;
# 86 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 84 -> 86;
# 87 [label="DemAge <= 75.5\ngini = 0.498\nsamples = 15\nvalue = [7, 8]"];
# 83 -> 87;
# 88 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]"];
# 87 -> 88;
# 89 [label="DemCluster_40 <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]"];
# 87 -> 89;
# 90 [label="PromCnt36 <= 39.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]"];
# 89 -> 90;
# 91 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]"];
# 90 -> 91;
# 92 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 90 -> 92;
# 93 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 89 -> 93;
# 94 [label="DemAge <= 22.5\ngini = 0.451\nsamples = 990\nvalue = [650, 340]"];
# 2 -> 94;
# 95 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 94 -> 95;
# 96 [label="DemCluster_42 <= 0.5\ngini = 0.449\nsamples = 986\nvalue = [650, 336]"];
# 94 -> 96;
# 97 [label="GiftAvgAll <= 38.325\ngini = 0.447\nsamples = 977\nvalue = [648, 329]"];
# 96 -> 97;
# 98 [label="DemCluster_50 <= 0.5\ngini = 0.451\nsamples = 959\nvalue = [630, 329]"];
# 97 -> 98;
# 99 [label="GiftAvgAll <= 35.275\ngini = 0.447\nsamples = 945\nvalue = [626, 319]"];
# 98 -> 99;
# 100 [label="DemCluster_24 <= 0.5\ngini = 0.445\nsamples = 939\nvalue = [625, 314]"];
# 99 -> 100;
# 101 [label="DemMedHomeValue <= 41550.0\ngini = 0.443\nsamples = 931\nvalue = [623, 308]"];
# 100 -> 101;
# 102 [label="GiftTimeFirst <= 99.5\ngini = 0.396\nsamples = 283\nvalue = [206, 77]"];
# 101 -> 102;
# 103 [label="GiftCntAll <= 4.5\ngini = 0.422\nsamples = 231\nvalue = [161, 70]"];
# 102 -> 103;
# 104 [label="DemGender_U <= 0.5\ngini = 0.374\nsamples = 173\nvalue = [130, 43]"];
# 103 -> 104;
# 105 [label="DemPctVeterans <= 19.5\ngini = 0.355\nsamples = 165\nvalue = [127, 38]"];
# 104 -> 105;
# 106 [label="gini = 0.0\nsamples = 23\nvalue = [23, 0]"];
# 105 -> 106;
# 107 [label="DemMedIncome <= 44896.5\ngini = 0.392\nsamples = 142\nvalue = [104, 38]"];
# 105 -> 107;
# 108 [label="DemPctVeterans <= 32.5\ngini = 0.444\nsamples = 93\nvalue = [62, 31]"];
# 107 -> 108;
# 109 [label="PromCntCard36 <= 4.5\ngini = 0.485\nsamples = 58\nvalue = [34, 24]"];
# 108 -> 109;
# 110 [label="StatusCatStarAll <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]"];
# 109 -> 110;
# 111 [label="gini = 0.0\nsamples = 10\nvalue = [10, 0]"];
# 110 -> 111;
# 112 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 110 -> 112;
# 113 [label="DemCluster_30 <= 0.5\ngini = 0.5\nsamples = 47\nvalue = [24, 23]"];
# 109 -> 113;
# 114 [label="DemPctVeterans <= 26.5\ngini = 0.498\nsamples = 43\nvalue = [20, 23]"];
# 113 -> 114;
# 115 [label="PromCntCard36 <= 9.5\ngini = 0.472\nsamples = 21\nvalue = [13, 8]"];
# 114 -> 115;
# 116 [label="PromCntAll <= 12.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]"];
# 115 -> 116;
# 117 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 116 -> 117;
# 118 [label="DemCluster_47 <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]"];
# 116 -> 118;
# 119 [label="gini = 0.0\nsamples = 10\nvalue = [10, 0]"];
# 118 -> 119;
# 120 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 118 -> 120;
# 121 [label="DemMedHomeValue <= 36150.0\ngini = 0.444\nsamples = 9\nvalue = [3, 6]"];
# 115 -> 121;
# 122 [label="DemCluster_31 <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]"];
# 121 -> 122;
# 123 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]"];
# 122 -> 123;
# 124 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 122 -> 124;
# 125 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 121 -> 125;
# 126 [label="PromCnt36 <= 29.5\ngini = 0.434\nsamples = 22\nvalue = [7, 15]"];
# 114 -> 126;
# 127 [label="PromCnt36 <= 16.5\ngini = 0.332\nsamples = 19\nvalue = [4, 15]"];
# 126 -> 127;
# 128 [label="DemMedIncome <= 38386.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]"];
# 127 -> 128;
# 129 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 128 -> 129;
# 130 [label="DemCluster_45 <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]"];
# 128 -> 130;
# 131 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"];
# 130 -> 131;
# 132 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 130 -> 132;
# 133 [label="GiftAvgCard36 <= 7.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]"];
# 127 -> 133;
# 134 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 133 -> 134;
# 135 [label="gini = 0.0\nsamples = 12\nvalue = [0, 12]"];
# 133 -> 135;
# 136 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"];
# 126 -> 136;
# 137 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 113 -> 137;
# 138 [label="DemPctVeterans <= 37.5\ngini = 0.32\nsamples = 35\nvalue = [28, 7]"];
# 108 -> 138;
# 139 [label="GiftTimeLast <= 23.0\ngini = 0.105\nsamples = 18\nvalue = [17, 1]"];
# 138 -> 139;
# 140 [label="gini = 0.0\nsamples = 16\nvalue = [16, 0]"];
# 139 -> 140;
# 141 [label="GiftCntCardAll <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 139 -> 141;
# 142 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 141 -> 142;
# 143 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 141 -> 143;
# 144 [label="GiftCntCardAll <= 0.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]"];
# 138 -> 144;
# 145 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 144 -> 145;
# 146 [label="GiftAvgCard36 <= 17.5\ngini = 0.391\nsamples = 15\nvalue = [11, 4]"];
# 144 -> 146;
# 147 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]"];
# 146 -> 147;
# 148 [label="DemMedHomeValue <= 40550.0\ngini = 0.5\nsamples = 8\nvalue = [4, 4]"];
# 146 -> 148;
# 149 [label="StatusCat96NK_N <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"];
# 148 -> 149;
# 150 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 149 -> 150;
# 151 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 149 -> 151;
# 152 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"];
# 148 -> 152;
# 153 [label="DemMedIncome <= 67253.5\ngini = 0.245\nsamples = 49\nvalue = [42, 7]"];
# 107 -> 153;
# 154 [label="GiftAvgLast <= 15.5\ngini = 0.219\nsamples = 48\nvalue = [42, 6]"];
# 153 -> 154;
# 155 [label="GiftTimeFirst <= 18.0\ngini = 0.408\nsamples = 21\nvalue = [15, 6]"];
# 154 -> 155;
# 156 [label="PromCnt12 <= 10.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"];
# 155 -> 156;
# 157 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 156 -> 157;
# 158 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 156 -> 158;
# 159 [label="DemCluster_27 <= 0.5\ngini = 0.291\nsamples = 17\nvalue = [14, 3]"];
# 155 -> 159;
# 160 [label="DemCluster_53 <= 0.5\ngini = 0.219\nsamples = 16\nvalue = [14, 2]"];
# 159 -> 160;
# 161 [label="GiftAvg36 <= 21.25\ngini = 0.124\nsamples = 15\nvalue = [14, 1]"];
# 160 -> 161;
# 162 [label="gini = 0.0\nsamples = 14\nvalue = [14, 0]"];
# 161 -> 162;
# 163 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 161 -> 163;
# 164 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 160 -> 164;
# 165 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 159 -> 165;
# 166 [label="gini = 0.0\nsamples = 27\nvalue = [27, 0]"];
# 154 -> 166;
# 167 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 153 -> 167;
# 168 [label="PromCntCard36 <= 13.0\ngini = 0.469\nsamples = 8\nvalue = [3, 5]"];
# 104 -> 168;
# 169 [label="DemCluster_12 <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"];
# 168 -> 169;
# 170 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"];
# 169 -> 170;
# 171 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 169 -> 171;
# 172 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 168 -> 172;
# 173 [label="GiftAvgCard36 <= 18.0\ngini = 0.498\nsamples = 58\nvalue = [31, 27]"];
# 103 -> 173;
# 174 [label="DemMedHomeValue <= 39600.0\ngini = 0.491\nsamples = 44\nvalue = [19, 25]"];
# 173 -> 174;
# 175 [label="DemMedIncome <= 37213.5\ngini = 0.5\nsamples = 37\nvalue = [19, 18]"];
# 174 -> 175;
# 176 [label="DemMedIncome <= 22173.0\ngini = 0.355\nsamples = 13\nvalue = [3, 10]"];
# 175 -> 176;
# 177 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 176 -> 177;
# 178 [label="DemCluster_9 <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]"];
# 176 -> 178;
# 179 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]"];
# 178 -> 179;
# 180 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 178 -> 180;
# 181 [label="GiftTimeLast <= 18.5\ngini = 0.444\nsamples = 24\nvalue = [16, 8]"];
# 175 -> 181;
# 182 [label="StatusCatStarAll <= 0.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]"];
# 181 -> 182;
# 183 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"];
# 182 -> 183;
# 184 [label="DemPctVeterans <= 28.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]"];
# 182 -> 184;
# 185 [label="PromCnt36 <= 30.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"];
# 184 -> 185;
# 186 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 185 -> 186;
# 187 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 185 -> 187;
# 188 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 184 -> 188;
# 189 [label="DemCluster_25 <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]"];
# 181 -> 189;
# 190 [label="gini = 0.0\nsamples = 10\nvalue = [10, 0]"];
# 189 -> 190;
# 191 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 189 -> 191;
# 192 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]"];
# 174 -> 192;
# 193 [label="DemCluster_51 <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]"];
# 173 -> 193;
# 194 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]"];
# 193 -> 194;
# 195 [label="DemMedHomeValue <= 34600.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"];
# 193 -> 195;
# 196 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 195 -> 196;
# 197 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 195 -> 197;
# 198 [label="GiftCntCardAll <= 14.0\ngini = 0.233\nsamples = 52\nvalue = [45, 7]"];
# 102 -> 198;
# 199 [label="StatusCat96NK_L <= 0.5\ngini = 0.183\nsamples = 49\nvalue = [44, 5]"];
# 198 -> 199;
# 200 [label="GiftTimeLast <= 26.5\ngini = 0.153\nsamples = 48\nvalue = [44, 4]"];
# 199 -> 200;
# 201 [label="DemCluster_10 <= 0.5\ngini = 0.12\nsamples = 47\nvalue = [44, 3]"];
# 200 -> 201;
# 202 [label="GiftCntCardAll <= 3.5\ngini = 0.085\nsamples = 45\nvalue = [43, 2]"];
# 201 -> 202;
# 203 [label="GiftAvg36 <= 23.75\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"];
# 202 -> 203;
# 204 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 203 -> 204;
# 205 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 203 -> 205;
# 206 [label="PromCnt12 <= 14.5\ngini = 0.046\nsamples = 42\nvalue = [41, 1]"];
# 202 -> 206;
# 207 [label="gini = 0.0\nsamples = 39\nvalue = [39, 0]"];
# 206 -> 207;
# 208 [label="PromCntAll <= 69.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"];
# 206 -> 208;
# 209 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 208 -> 209;
# 210 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 208 -> 210;
# 211 [label="StatusCatStarAll <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 201 -> 211;
# 212 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 211 -> 212;
# 213 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 211 -> 213;
# 214 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 200 -> 214;
# 215 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 199 -> 215;
# 216 [label="GiftAvgAll <= 18.43\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"];
# 198 -> 216;
# 217 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 216 -> 217;
# 218 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 216 -> 218;
# 219 [label="GiftCntAll <= 15.5\ngini = 0.459\nsamples = 648\nvalue = [417, 231]"];
# 101 -> 219;
# 220 [label="DemMedHomeValue <= 44350.0\ngini = 0.453\nsamples = 626\nvalue = [409, 217]"];
# 219 -> 220;
# 221 [label="GiftAvgAll <= 16.895\ngini = 0.499\nsamples = 81\nvalue = [42, 39]"];
# 220 -> 221;
# 222 [label="DemMedIncome <= 40459.0\ngini = 0.49\nsamples = 58\nvalue = [25, 33]"];
# 221 -> 222;
# 223 [label="PromCntAll <= 21.5\ngini = 0.463\nsamples = 22\nvalue = [14, 8]"];
# 222 -> 223;
# 224 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 223 -> 224;
# 225 [label="GiftTimeLast <= 22.5\ngini = 0.388\nsamples = 19\nvalue = [14, 5]"];
# 223 -> 225;
# 226 [label="DemAge <= 32.0\ngini = 0.231\nsamples = 15\nvalue = [13, 2]"];
# 225 -> 226;
# 227 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 226 -> 227;
# 228 [label="DemCluster_49 <= 0.5\ngini = 0.133\nsamples = 14\nvalue = [13, 1]"];
# 226 -> 228;
# 229 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"];
# 228 -> 229;
# 230 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 228 -> 230;
# 231 [label="DemPctVeterans <= 33.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"];
# 225 -> 231;
# 232 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 231 -> 232;
# 233 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 231 -> 233;
# 234 [label="PromCntAll <= 38.5\ngini = 0.424\nsamples = 36\nvalue = [11, 25]"];
# 222 -> 234;
# 235 [label="GiftTimeFirst <= 42.0\ngini = 0.498\nsamples = 17\nvalue = [9, 8]"];
# 234 -> 235;
# 236 [label="DemCluster_47 <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8]"];
# 235 -> 236;
# 237 [label="GiftTimeLast <= 25.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]"];
# 236 -> 237;
# 238 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]"];
# 237 -> 238;
# 239 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 237 -> 239;
# 240 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 236 -> 240;
# 241 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]"];
# 235 -> 241;
# 242 [label="DemAge <= 82.0\ngini = 0.188\nsamples = 19\nvalue = [2, 17]"];
# 234 -> 242;
# 243 [label="DemCluster_49 <= 0.5\ngini = 0.105\nsamples = 18\nvalue = [1, 17]"];
# 242 -> 243;
# 244 [label="gini = 0.0\nsamples = 15\nvalue = [0, 15]"];
# 243 -> 244;
# 245 [label="PromCnt12 <= 10.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"];
# 243 -> 245;
# 246 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 245 -> 246;
# 247 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 245 -> 247;
# 248 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 242 -> 248;
# 249 [label="GiftAvgCard36 <= 25.5\ngini = 0.386\nsamples = 23\nvalue = [17, 6]"];
# 221 -> 249;
# 250 [label="DemPctVeterans <= 12.5\ngini = 0.308\nsamples = 21\nvalue = [17, 4]"];
# 249 -> 250;
# 251 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 250 -> 251;
# 252 [label="DemAge <= 80.5\ngini = 0.255\nsamples = 20\nvalue = [17, 3]"];
# 250 -> 252;
# 253 [label="DemCluster_51 <= 0.5\ngini = 0.188\nsamples = 19\nvalue = [17, 2]"];
# 252 -> 253;
# 254 [label="DemCluster_41 <= 0.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]"];
# 253 -> 254;
# 255 [label="gini = 0.0\nsamples = 16\nvalue = [16, 0]"];
# 254 -> 255;
# 256 [label="DemHomeOwner <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 254 -> 256;
# 257 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 256 -> 257;
# 258 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 256 -> 258;
# 259 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 253 -> 259;
# 260 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 252 -> 260;
# 261 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 249 -> 261;
# 262 [label="PromCntCard12 <= 6.5\ngini = 0.44\nsamples = 545\nvalue = [367, 178]"];
# 220 -> 262;
# 263 [label="DemCluster_9 <= 0.5\ngini = 0.436\nsamples = 541\nvalue = [367, 174]"];
# 262 -> 263;
# 264 [label="DemPctVeterans <= 63.0\ngini = 0.432\nsamples = 535\nvalue = [366, 169]"];
# 263 -> 264;
# 265 [label="GiftAvg36 <= 26.75\ngini = 0.429\nsamples = 530\nvalue = [365, 165]"];
# 264 -> 265;
# 266 [label="GiftTimeLast <= 25.5\ngini = 0.436\nsamples = 508\nvalue = [345, 163]"];
# 265 -> 266;
# 267 [label="DemMedHomeValue <= 62900.0\ngini = 0.445\nsamples = 463\nvalue = [308, 155]"];
# 266 -> 267;
# 268 [label="DemCluster_45 <= 0.5\ngini = 0.458\nsamples = 400\nvalue = [258, 142]"];
# 267 -> 268;
# 269 [label="GiftAvgLast <= 26.5\ngini = 0.464\nsamples = 386\nvalue = [245, 141]"];
# 268 -> 269;
# 270 [label="DemAge <= 82.5\ngini = 0.46\nsamples = 380\nvalue = [244, 136]"];
# 269 -> 270;
# 271 [label="PromCntCard36 <= 6.5\ngini = 0.466\nsamples = 366\nvalue = [231, 135]"];
# 270 -> 271;
# 272 [label="DemMedIncome <= 40713.0\ngini = 0.489\nsamples = 181\nvalue = [104, 77]"];
# 271 -> 272;
# 273 [label="GiftAvgLast <= 22.5\ngini = 0.346\nsamples = 54\nvalue = [42, 12]"];
# 272 -> 273;
# 274 [label="DemCluster_20 <= 0.5\ngini = 0.227\nsamples = 46\nvalue = [40, 6]"];
# 273 -> 274;
# 275 [label="DemPctVeterans <= 40.5\ngini = 0.198\nsamples = 45\nvalue = [40, 5]"];
# 274 -> 275;
# 276 [label="DemCluster_51 <= 0.5\ngini = 0.111\nsamples = 34\nvalue = [32, 2]"];
# 275 -> 276;
# 277 [label="GiftAvgCard36 <= 17.5\ngini = 0.061\nsamples = 32\nvalue = [31, 1]"];
# 276 -> 277;
# 278 [label="gini = 0.0\nsamples = 29\nvalue = [29, 0]"];
# 277 -> 278;
# 279 [label="DemCluster_36 <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"];
# 277 -> 279;
# 280 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 279 -> 280;
# 281 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 279 -> 281;
# 282 [label="PromCntAll <= 14.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 276 -> 282;
# 283 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 282 -> 283;
# 284 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 282 -> 284;
# 285 [label="GiftTimeLast <= 19.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]"];
# 275 -> 285;
# 286 [label="PromCntCardAll <= 10.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]"];
# 285 -> 286;
# 287 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 286 -> 287;
# 288 [label="PromCntAll <= 55.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"];
# 286 -> 288;
# 289 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 288 -> 289;
# 290 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 288 -> 290;
# 291 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 285 -> 291;
# 292 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 274 -> 292;
# 293 [label="GiftCntCardAll <= 3.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]"];
# 273 -> 293;
# 294 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]"];
# 293 -> 294;
# 295 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 293 -> 295;
# 296 [label="GiftCntAll <= 8.5\ngini = 0.5\nsamples = 127\nvalue = [62, 65]"];
# 272 -> 296;
# 297 [label="DemPctVeterans <= 15.5\ngini = 0.49\nsamples = 105\nvalue = [45, 60]"];
# 296 -> 297;
# 298 [label="DemAge <= 26.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]"];
# 297 -> 298;
# 299 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 298 -> 299;
# 300 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 298 -> 300;
# 301 [label="DemMedIncome <= 42656.5\ngini = 0.482\nsamples = 99\nvalue = [40, 59]"];
# 297 -> 301;
# 302 [label="GiftAvgAll <= 19.645\ngini = 0.231\nsamples = 15\nvalue = [2, 13]"];
# 301 -> 302;
# 303 [label="gini = 0.0\nsamples = 12\nvalue = [0, 12]"];
# 302 -> 303;
# 304 [label="DemMedHomeValue <= 50750.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"];
# 302 -> 304;
# 305 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 304 -> 305;
# 306 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 304 -> 306;
# 307 [label="DemCluster_8 <= 0.5\ngini = 0.495\nsamples = 84\nvalue = [38, 46]"];
# 301 -> 307;
# 308 [label="DemCluster_47 <= 0.5\ngini = 0.489\nsamples = 80\nvalue = [34, 46]"];
# 307 -> 308;
# 309 [label="DemAge <= 62.0\ngini = 0.477\nsamples = 74\nvalue = [29, 45]"];
# 308 -> 309;
# 310 [label="GiftAvgAll <= 11.35\ngini = 0.497\nsamples = 54\nvalue = [25, 29]"];
# 309 -> 310;
# 311 [label="DemGender_M <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]"];
# 310 -> 311;
# 312 [label="gini = 0.0\nsamples = 8\nvalue = [8, 0]"];
# 311 -> 312;
# 313 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 311 -> 313;
# 314 [label="DemMedHomeValue <= 49000.0\ngini = 0.478\nsamples = 43\nvalue = [17, 26]"];
# 310 -> 314;
# 315 [label="DemPctVeterans <= 20.0\ngini = 0.18\nsamples = 10\nvalue = [1, 9]"];
# 314 -> 315;
# 316 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 315 -> 316;
# 317 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]"];
# 315 -> 317;
# 318 [label="GiftAvgCard36 <= 14.612\ngini = 0.5\nsamples = 33\nvalue = [16, 17]"];
# 314 -> 318;
# 319 [label="DemMedHomeValue <= 49900.0\ngini = 0.469\nsamples = 24\nvalue = [9, 15]"];
# 318 -> 319;
# 320 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"];
# 319 -> 320;
# 321 [label="PromCnt36 <= 30.5\ngini = 0.408\nsamples = 21\nvalue = [6, 15]"];
# 319 -> 321;
# 322 [label="DemMedIncome <= 43759.5\ngini = 0.219\nsamples = 16\nvalue = [2, 14]"];
# 321 -> 322;
# 323 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 322 -> 323;
# 324 [label="DemCluster_40 <= 0.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14]"];
# 322 -> 324;
# 325 [label="gini = 0.0\nsamples = 14\nvalue = [0, 14]"];
# 324 -> 325;
# 326 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 324 -> 326;
# 327 [label="GiftAvg36 <= 16.25\ngini = 0.32\nsamples = 5\nvalue = [4, 1]"];
# 321 -> 327;
# 328 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 327 -> 328;
# 329 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 327 -> 329;
# 330 [label="PromCntCardAll <= 14.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]"];
# 318 -> 330;
# 331 [label="DemCluster_21 <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]"];
# 330 -> 331;
# 332 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]"];
# 331 -> 332;
# 333 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 331 -> 333;
# 334 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 330 -> 334;
# 335 [label="GiftAvg36 <= 19.0\ngini = 0.32\nsamples = 20\nvalue = [4, 16]"];
# 309 -> 335;
# 336 [label="DemCluster_10 <= 0.5\ngini = 0.133\nsamples = 14\nvalue = [1, 13]"];
# 335 -> 336;
# 337 [label="gini = 0.0\nsamples = 13\nvalue = [0, 13]"];
# 336 -> 337;
# 338 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 336 -> 338;
# 339 [label="PromCntAll <= 17.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]"];
# 335 -> 339;
# 340 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 339 -> 340;
# 341 [label="GiftTimeLast <= 18.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]"];
# 339 -> 341;
# 342 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"];
# 341 -> 342;
# 343 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 341 -> 343;
# 344 [label="GiftAvgCard36 <= 16.112\ngini = 0.278\nsamples = 6\nvalue = [5, 1]"];
# 308 -> 344;
# 345 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 344 -> 345;
# 346 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 344 -> 346;
# 347 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 307 -> 347;
# 348 [label="PromCntCardAll <= 30.5\ngini = 0.351\nsamples = 22\nvalue = [17, 5]"];
# 296 -> 348;
# 349 [label="GiftAvgAll <= 17.825\ngini = 0.198\nsamples = 18\nvalue = [16, 2]"];
# 348 -> 349;
# 350 [label="DemCluster_46 <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [16, 1]"];
# 349 -> 350;
# 351 [label="gini = 0.0\nsamples = 16\nvalue = [16, 0]"];
# 350 -> 351;
# 352 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 350 -> 352;
# 353 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 349 -> 353;
# 354 [label="GiftAvgAll <= 15.24\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"];
# 348 -> 354;
# 355 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 354 -> 355;
# 356 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 354 -> 356;
# 357 [label="DemMedIncome <= 35997.0\ngini = 0.43\nsamples = 185\nvalue = [127, 58]"];
# 271 -> 357;
# 358 [label="DemAge <= 57.5\ngini = 0.483\nsamples = 22\nvalue = [9, 13]"];
# 357 -> 358;
# 359 [label="DemAge <= 48.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]"];
# 358 -> 359;
# 360 [label="DemMedIncome <= 32272.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]"];
# 359 -> 360;
# 361 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 360 -> 361;
# 362 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 360 -> 362;
# 363 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 359 -> 363;
# 364 [label="DemPctVeterans <= 22.0\ngini = 0.278\nsamples = 12\nvalue = [2, 10]"];
# 358 -> 364;
# 365 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 364 -> 365;
# 366 [label="GiftAvgAll <= 8.51\ngini = 0.165\nsamples = 11\nvalue = [1, 10]"];
# 364 -> 366;
# 367 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 366 -> 367;
# 368 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]"];
# 366 -> 368;
# 369 [label="GiftTimeFirst <= 127.5\ngini = 0.4\nsamples = 163\nvalue = [118, 45]"];
# 357 -> 369;
# 370 [label="DemCluster_12 <= 0.5\ngini = 0.391\nsamples = 161\nvalue = [118, 43]"];
# 369 -> 370;
# 371 [label="DemAge <= 50.5\ngini = 0.383\nsamples = 159\nvalue = [118, 41]"];
# 370 -> 371;
# 372 [label="PromCntCard36 <= 9.5\ngini = 0.472\nsamples = 42\nvalue = [26, 16]"];
# 371 -> 372;
# 373 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]"];
# 372 -> 373;
# 374 [label="DemPctVeterans <= 34.5\ngini = 0.499\nsamples = 31\nvalue = [15, 16]"];
# 372 -> 374;
# 375 [label="DemPctVeterans <= 30.5\ngini = 0.408\nsamples = 21\nvalue = [6, 15]"];
# 374 -> 375;
# 376 [label="GiftTimeLast <= 22.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]"];
# 375 -> 376;
# 377 [label="GiftTimeLast <= 17.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"];
# 376 -> 377;
# 378 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 377 -> 378;
# 379 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"];
# 377 -> 379;
# 380 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 376 -> 380;
# 381 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]"];
# 375 -> 381;
# 382 [label="GiftAvg36 <= 12.75\ngini = 0.18\nsamples = 10\nvalue = [9, 1]"];
# 374 -> 382;
# 383 [label="PromCntCard12 <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 382 -> 383;
# 384 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 383 -> 384;
# 385 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 383 -> 385;
# 386 [label="gini = 0.0\nsamples = 8\nvalue = [8, 0]"];
# 382 -> 386;
# 387 [label="DemCluster_31 <= 0.5\ngini = 0.336\nsamples = 117\nvalue = [92, 25]"];
# 371 -> 387;
# 388 [label="DemPctVeterans <= 46.0\ngini = 0.311\nsamples = 114\nvalue = [92, 22]"];
# 387 -> 388;
# 389 [label="GiftTimeLast <= 24.5\ngini = 0.286\nsamples = 110\nvalue = [91, 19]"];
# 388 -> 389;
# 390 [label="PromCntCardAll <= 9.5\ngini = 0.267\nsamples = 107\nvalue = [90, 17]"];
# 389 -> 390;
# 391 [label="DemMedHomeValue <= 60500.0\ngini = 0.405\nsamples = 39\nvalue = [28, 11]"];
# 390 -> 391;
# 392 [label="DemPctVeterans <= 29.5\ngini = 0.353\nsamples = 35\nvalue = [27, 8]"];
# 391 -> 392;
# 393 [label="DemCluster_10 <= 0.5\ngini = 0.18\nsamples = 20\nvalue = [18, 2]"];
# 392 -> 393;
# 394 [label="GiftTimeLast <= 23.5\ngini = 0.1\nsamples = 19\nvalue = [18, 1]"];
# 393 -> 394;
# 395 [label="gini = 0.0\nsamples = 17\nvalue = [17, 0]"];
# 394 -> 395;
# 396 [label="DemCluster_40 <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 394 -> 396;
# 397 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 396 -> 397;
# 398 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 396 -> 398;
# 399 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 393 -> 399;
# 400 [label="DemPctVeterans <= 32.5\ngini = 0.48\nsamples = 15\nvalue = [9, 6]"];
# 392 -> 400;
# 401 [label="DemMedIncome <= 49517.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]"];
# 400 -> 401;
# 402 [label="PromCntAll <= 15.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"];
# 401 -> 402;
# 403 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 402 -> 403;
# 404 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 402 -> 404;
# 405 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 401 -> 405;
# 406 [label="GiftCntCard36 <= 1.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]"];
# 400 -> 406;
# 407 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]"];
# 406 -> 407;
# 408 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 406 -> 408;
# 409 [label="DemAge <= 55.075\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"];
# 391 -> 409;
# 410 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 409 -> 410;
# 411 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 409 -> 411;
# 412 [label="DemPctVeterans <= 35.5\ngini = 0.161\nsamples = 68\nvalue = [62, 6]"];
# 390 -> 412;
# 413 [label="gini = 0.0\nsamples = 44\nvalue = [44, 0]"];
# 412 -> 413;
# 414 [label="GiftAvgAll <= 10.785\ngini = 0.375\nsamples = 24\nvalue = [18, 6]"];
# 412 -> 414;
# 415 [label="DemMedHomeValue <= 55750.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]"];
# 414 -> 415;
# 416 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 415 -> 416;
# 417 [label="DemAge <= 56.075\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"];
# 415 -> 417;
# 418 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 417 -> 418;
# 419 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"];
# 417 -> 419;
# 420 [label="DemCluster_49 <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]"];
# 414 -> 420;
# 421 [label="gini = 0.0\nsamples = 12\nvalue = [12, 0]"];
# 420 -> 421;
# 422 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 420 -> 422;
# 423 [label="DemPctVeterans <= 33.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"];
# 389 -> 423;
# 424 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 423 -> 424;
# 425 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 423 -> 425;
# 426 [label="GiftCntAll <= 2.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"];
# 388 -> 426;
# 427 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 426 -> 427;
# 428 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 426 -> 428;
# 429 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 387 -> 429;
# 430 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 370 -> 430;
# 431 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 369 -> 431;
# 432 [label="DemMedIncome <= 55006.729\ngini = 0.133\nsamples = 14\nvalue = [13, 1]"];
# 270 -> 432;
# 433 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"];
# 432 -> 433;
# 434 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 432 -> 434;
# 435 [label="GiftTimeFirst <= 103.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"];
# 269 -> 435;
# 436 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"];
# 435 -> 436;
# 437 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 435 -> 437;
# 438 [label="GiftAvgCard36 <= 9.612\ngini = 0.133\nsamples = 14\nvalue = [13, 1]"];
# 268 -> 438;
# 439 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 438 -> 439;
# 440 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"];
# 438 -> 440;
# 441 [label="GiftTimeFirst <= 32.5\ngini = 0.328\nsamples = 63\nvalue = [50, 13]"];
# 267 -> 441;
# 442 [label="PromCnt36 <= 23.5\ngini = 0.452\nsamples = 29\nvalue = [19, 10]"];
# 441 -> 442;
# 443 [label="GiftAvg36 <= 17.5\ngini = 0.375\nsamples = 24\nvalue = [18, 6]"];
# 442 -> 443;
# 444 [label="DemCluster_17 <= 0.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]"];
# 443 -> 444;
# 445 [label="gini = 0.0\nsamples = 15\nvalue = [15, 0]"];
# 444 -> 445;
# 446 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 444 -> 446;
# 447 [label="DemAge <= 45.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]"];
# 443 -> 447;
# 448 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 447 -> 448;
# 449 [label="DemPctVeterans <= 22.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"];
# 447 -> 449;
# 450 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 449 -> 450;
# 451 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"];
# 449 -> 451;
# 452 [label="GiftAvg36 <= 21.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"];
# 442 -> 452;
# 453 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 452 -> 453;
# 454 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 452 -> 454;
# 455 [label="DemCluster_18 <= 0.5\ngini = 0.161\nsamples = 34\nvalue = [31, 3]"];
# 441 -> 455;
# 456 [label="DemMedIncome <= 33573.5\ngini = 0.114\nsamples = 33\nvalue = [31, 2]"];
# 455 -> 456;
# 457 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 456 -> 457;
# 458 [label="DemCluster_44 <= 0.5\ngini = 0.061\nsamples = 32\nvalue = [31, 1]"];
# 456 -> 458;
# 459 [label="gini = 0.0\nsamples = 30\nvalue = [30, 0]"];
# 458 -> 459;
# 460 [label="PromCntCard12 <= 5.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 458 -> 460;
# 461 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 460 -> 461;
# 462 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 460 -> 462;
# 463 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 455 -> 463;
# 464 [label="DemMedIncome <= 30066.0\ngini = 0.292\nsamples = 45\nvalue = [37, 8]"];
# 266 -> 464;
# 465 [label="PromCntCard36 <= 11.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]"];
# 464 -> 465;
# 466 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 465 -> 466;
# 467 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 465 -> 467;
# 468 [label="PromCntAll <= 61.5\ngini = 0.184\nsamples = 39\nvalue = [35, 4]"];
# 464 -> 468;
# 469 [label="gini = 0.0\nsamples = 31\nvalue = [31, 0]"];
# 468 -> 469;
# 470 [label="GiftAvgAll <= 10.88\ngini = 0.5\nsamples = 8\nvalue = [4, 4]"];
# 468 -> 470;
# 471 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 470 -> 471;
# 472 [label="DemPctVeterans <= 33.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]"];
# 470 -> 472;
# 473 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 472 -> 473;
# 474 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 472 -> 474;
# 475 [label="DemCluster_11 <= 0.5\ngini = 0.165\nsamples = 22\nvalue = [20, 2]"];
# 265 -> 475;
# 476 [label="DemCluster_51 <= 0.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]"];
# 475 -> 476;
# 477 [label="gini = 0.0\nsamples = 20\nvalue = [20, 0]"];
# 476 -> 477;
# 478 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 476 -> 478;
# 479 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 475 -> 479;
# 480 [label="GiftAvg36 <= 12.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"];
# 264 -> 480;
# 481 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 480 -> 481;
# 482 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 480 -> 482;
# 483 [label="DemAge <= 76.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"];
# 263 -> 483;
# 484 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"];
# 483 -> 484;
# 485 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 483 -> 485;
# 486 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 262 -> 486;
# 487 [label="GiftTimeFirst <= 128.5\ngini = 0.463\nsamples = 22\nvalue = [8, 14]"];
# 219 -> 487;
# 488 [label="DemCluster_36 <= 0.5\ngini = 0.305\nsamples = 16\nvalue = [3, 13]"];
# 487 -> 488;
# 489 [label="GiftTimeFirst <= 96.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]"];
# 488 -> 489;
# 490 [label="PromCntCardAll <= 23.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 489 -> 490;
# 491 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 490 -> 491;
# 492 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 490 -> 492;
# 493 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]"];
# 489 -> 493;
# 494 [label="PromCntCard12 <= 5.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"];
# 488 -> 494;
# 495 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 494 -> 495;
# 496 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 494 -> 496;
# 497 [label="DemGender_M <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]"];
# 487 -> 497;
# 498 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 497 -> 498;
# 499 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 497 -> 499;
# 500 [label="GiftTimeLast <= 22.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]"];
# 100 -> 500;
# 501 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"];
# 500 -> 501;
# 502 [label="DemMedIncome <= 46429.229\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"];
# 500 -> 502;
# 503 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 502 -> 503;
# 504 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 502 -> 504;
# 505 [label="GiftCntAll <= 3.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"];
# 99 -> 505;
# 506 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 505 -> 506;
# 507 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"];
# 505 -> 507;
# 508 [label="GiftAvgCard36 <= 11.5\ngini = 0.408\nsamples = 14\nvalue = [4, 10]"];
# 98 -> 508;
# 509 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 508 -> 509;
# 510 [label="DemMedHomeValue <= 34950.0\ngini = 0.278\nsamples = 12\nvalue = [2, 10]"];
# 508 -> 510;
# 511 [label="DemAge <= 51.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"];
# 510 -> 511;
# 512 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 511 -> 512;
# 513 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 511 -> 513;
# 514 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]"];
# 510 -> 514;
# 515 [label="gini = 0.0\nsamples = 18\nvalue = [18, 0]"];
# 97 -> 515;
# 516 [label="DemMedIncome <= 46375.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]"];
# 96 -> 516;
# 517 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]"];
# 516 -> 517;
# 518 [label="GiftCntCard36 <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"];
# 516 -> 518;
# 519 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 518 -> 519;
# 520 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 518 -> 520;
# 521 [label="PromCnt12 <= 6.5\ngini = 0.497\nsamples = 1907\nvalue = [1030, 877]"];
# 1 -> 521;
# 522 [label="GiftAvgAll <= 15.915\ngini = 0.426\nsamples = 39\nvalue = [12, 27]"];
# 521 -> 522;
# 523 [label="DemPctVeterans <= 18.0\ngini = 0.32\nsamples = 30\nvalue = [6, 24]"];
# 522 -> 523;
# 524 [label="GiftAvg36 <= 16.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"];
# 523 -> 524;
# 525 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 524 -> 525;
# 526 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 524 -> 526;
# 527 [label="GiftAvg36 <= 27.5\ngini = 0.252\nsamples = 27\nvalue = [4, 23]"];
# 523 -> 527;
# 528 [label="StatusCat96NK_F <= 0.5\ngini = 0.204\nsamples = 26\nvalue = [3, 23]"];
# 527 -> 528;
# 529 [label="DemCluster_15 <= 0.5\ngini = 0.147\nsamples = 25\nvalue = [2, 23]"];
# 528 -> 529;
# 530 [label="DemCluster_34 <= 0.5\ngini = 0.08\nsamples = 24\nvalue = [1, 23]"];
# 529 -> 530;
# 531 [label="gini = 0.0\nsamples = 23\nvalue = [0, 23]"];
# 530 -> 531;
# 532 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 530 -> 532;
# 533 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 529 -> 533;
# 534 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 528 -> 534;
# 535 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 527 -> 535;
# 536 [label="PromCnt12 <= 3.0\ngini = 0.444\nsamples = 9\nvalue = [6, 3]"];
# 522 -> 536;
# 537 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 536 -> 537;
# 538 [label="DemCluster_24 <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"];
# 536 -> 538;
# 539 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"];
# 538 -> 539;
# 540 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 538 -> 540;
# 541 [label="PromCnt12 <= 14.5\ngini = 0.496\nsamples = 1868\nvalue = [1018, 850]"];
# 521 -> 541;
# 542 [label="DemMedHomeValue <= 546850.0\ngini = 0.494\nsamples = 1688\nvalue = [939, 749]"];
# 541 -> 542;
# 543 [label="DemMedHomeValue <= 70050.0\ngini = 0.493\nsamples = 1666\nvalue = [933, 733]"];
# 542 -> 543;
# 544 [label="PromCnt36 <= 29.5\ngini = 0.49\nsamples = 91\nvalue = [39, 52]"];
# 543 -> 544;
# 545 [label="DemAge <= 71.5\ngini = 0.48\nsamples = 50\nvalue = [30, 20]"];
# 544 -> 545;
# 546 [label="DemHomeOwner <= 0.5\ngini = 0.433\nsamples = 41\nvalue = [28, 13]"];
# 545 -> 546;
# 547 [label="DemAge <= 35.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]"];
# 546 -> 547;
# 548 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 547 -> 548;
# 549 [label="gini = 0.0\nsamples = 15\nvalue = [15, 0]"];
# 547 -> 549;
# 550 [label="PromCnt36 <= 16.5\ngini = 0.499\nsamples = 25\nvalue = [13, 12]"];
# 546 -> 550;
# 551 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"];
# 550 -> 551;
# 552 [label="PromCnt12 <= 9.5\ngini = 0.455\nsamples = 20\nvalue = [13, 7]"];
# 550 -> 552;
# 553 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 552 -> 553;
# 554 [label="DemPctVeterans <= 20.0\ngini = 0.401\nsamples = 18\nvalue = [13, 5]"];
# 552 -> 554;
# 555 [label="DemAge <= 53.575\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"];
# 554 -> 555;
# 556 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 555 -> 556;
# 557 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 555 -> 557;
# 558 [label="DemMedIncome <= 68935.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]"];
# 554 -> 558;
# 559 [label="DemCluster_41 <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]"];
# 558 -> 559;
# 560 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]"];
# 559 -> 560;
# 561 [label="DemPctVeterans <= 42.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 559 -> 561;
# 562 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 561 -> 562;
# 563 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 561 -> 563;
# 564 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 558 -> 564;
# 565 [label="PromCntCardAll <= 18.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]"];
# 545 -> 565;
# 566 [label="DemMedHomeValue <= 67950.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]"];
# 565 -> 566;
# 567 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 566 -> 567;
# 568 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]"];
# 566 -> 568;
# 569 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 565 -> 569;
# 570 [label="GiftAvgLast <= 24.5\ngini = 0.343\nsamples = 41\nvalue = [9, 32]"];
# 544 -> 570;
# 571 [label="DemCluster_37 <= 0.5\ngini = 0.219\nsamples = 32\nvalue = [4, 28]"];
# 570 -> 571;
# 572 [label="DemCluster_26 <= 0.5\ngini = 0.175\nsamples = 31\nvalue = [3, 28]"];
# 571 -> 572;
# 573 [label="DemCluster_18 <= 0.5\ngini = 0.124\nsamples = 30\nvalue = [2, 28]"];
# 572 -> 573;
# 574 [label="DemCluster_27 <= 0.5\ngini = 0.067\nsamples = 29\nvalue = [1, 28]"];
# 573 -> 574;
# 575 [label="gini = 0.0\nsamples = 26\nvalue = [0, 26]"];
# 574 -> 575;
# 576 [label="DemGender_F <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"];
# 574 -> 576;
# 577 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 576 -> 577;
# 578 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 576 -> 578;
# 579 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 573 -> 579;
# 580 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 572 -> 580;
# 581 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 571 -> 581;
# 582 [label="DemPctVeterans <= 30.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]"];
# 570 -> 582;
# 583 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 582 -> 583;
# 584 [label="GiftAvgCard36 <= 23.75\ngini = 0.278\nsamples = 6\nvalue = [5, 1]"];
# 582 -> 584;
# 585 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 584 -> 585;
# 586 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 584 -> 586;
# 587 [label="DemMedIncome <= 30148.0\ngini = 0.491\nsamples = 1575\nvalue = [894, 681]"];
# 543 -> 587;
# 588 [label="DemCluster_24 <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]"];
# 587 -> 588;
# 589 [label="gini = 0.0\nsamples = 12\nvalue = [12, 0]"];
# 588 -> 589;
# 590 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 588 -> 590;
# 591 [label="DemCluster_15 <= 0.5\ngini = 0.492\nsamples = 1562\nvalue = [882, 680]"];
# 587 -> 591;
# 592 [label="DemMedHomeValue <= 100950.0\ngini = 0.493\nsamples = 1534\nvalue = [860, 674]"];
# 591 -> 592;
# 593 [label="DemMedHomeValue <= 97850.0\ngini = 0.48\nsamples = 588\nvalue = [353, 235]"];
# 592 -> 593;
# 594 [label="GiftAvgAll <= 11.47\ngini = 0.486\nsamples = 550\nvalue = [321, 229]"];
# 593 -> 594;
# 595 [label="GiftAvgAll <= 7.59\ngini = 0.499\nsamples = 163\nvalue = [78, 85]"];
# 594 -> 595;
# 596 [label="GiftAvgAll <= 5.21\ngini = 0.394\nsamples = 37\nvalue = [27, 10]"];
# 595 -> 596;
# 597 [label="DemCluster_8 <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"];
# 596 -> 597;
# 598 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 597 -> 598;
# 599 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 597 -> 599;
# 600 [label="GiftAvg36 <= 17.5\ngini = 0.305\nsamples = 32\nvalue = [26, 6]"];
# 596 -> 600;
# ...
# 2770 -> 2788;
# 2789 [label="DemMedHomeValue <= 57600.0\ngini = 0.439\nsamples = 40\nvalue = [13, 27]"];
# 2769 -> 2789;
# 2790 [label="PromCntAll <= 38.5\ngini = 0.473\nsamples = 13\nvalue = [8, 5]"];
# 2789 -> 2790;
# 2791 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 2790 -> 2791;
# 2792 [label="DemMedHomeValue <= 48050.0\ngini = 0.397\nsamples = 11\nvalue = [8, 3]"];
# 2790 -> 2792;
# 2793 [label="PromCnt36 <= 34.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]"];
# 2792 -> 2793;
# 2794 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 2793 -> 2794;
# 2795 [label="DemMedHomeValue <= 43600.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"];
# 2793 -> 2795;
# 2796 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2795 -> 2796;
# 2797 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 2795 -> 2797;
# 2798 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 2792 -> 2798;
# 2799 [label="GiftCntAll <= 8.5\ngini = 0.302\nsamples = 27\nvalue = [5, 22]"];
# 2789 -> 2799;
# 2800 [label="GiftAvgCard36 <= 20.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]"];
# 2799 -> 2800;
# 2801 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"];
# 2800 -> 2801;
# 2802 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 2800 -> 2802;
# 2803 [label="DemCluster_46 <= 0.5\ngini = 0.165\nsamples = 22\nvalue = [2, 20]"];
# 2799 -> 2803;
# 2804 [label="PromCntAll <= 76.0\ngini = 0.091\nsamples = 21\nvalue = [1, 20]"];
# 2803 -> 2804;
# 2805 [label="gini = 0.0\nsamples = 20\nvalue = [0, 20]"];
# 2804 -> 2805;
# 2806 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2804 -> 2806;
# 2807 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2803 -> 2807;
# 2808 [label="PromCnt36 <= 34.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]"];
# 2768 -> 2808;
# 2809 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 2808 -> 2809;
# 2810 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 2808 -> 2810;
# 2811 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 2657 -> 2811;
# 2812 [label="GiftAvgAll <= 6.13\ngini = 0.5\nsamples = 228\nvalue = [117, 111]"];
# 2656 -> 2812;
# 2813 [label="DemPctVeterans <= 21.5\ngini = 0.458\nsamples = 45\nvalue = [16, 29]"];
# 2812 -> 2813;
# 2814 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 2813 -> 2814;
# 2815 [label="DemAge <= 80.5\ngini = 0.414\nsamples = 41\nvalue = [12, 29]"];
# 2813 -> 2815;
# 2816 [label="DemMedIncome <= 49269.5\ngini = 0.381\nsamples = 39\nvalue = [10, 29]"];
# 2815 -> 2816;
# 2817 [label="GiftCntAll <= 24.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]"];
# 2816 -> 2817;
# 2818 [label="GiftAvgCard36 <= 5.25\ngini = 0.444\nsamples = 9\nvalue = [6, 3]"];
# 2817 -> 2818;
# 2819 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 2818 -> 2819;
# 2820 [label="PromCntAll <= 39.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"];
# 2818 -> 2820;
# 2821 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2820 -> 2821;
# 2822 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"];
# 2820 -> 2822;
# 2823 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 2817 -> 2823;
# 2824 [label="DemCluster_53 <= 0.5\ngini = 0.26\nsamples = 26\nvalue = [4, 22]"];
# 2816 -> 2824;
# 2825 [label="DemCluster_10 <= 0.5\ngini = 0.211\nsamples = 25\nvalue = [3, 22]"];
# 2824 -> 2825;
# 2826 [label="DemMedIncome <= 78388.5\ngini = 0.153\nsamples = 24\nvalue = [2, 22]"];
# 2825 -> 2826;
# 2827 [label="DemCluster_40 <= 0.5\ngini = 0.083\nsamples = 23\nvalue = [1, 22]"];
# 2826 -> 2827;
# 2828 [label="gini = 0.0\nsamples = 20\nvalue = [0, 20]"];
# 2827 -> 2828;
# 2829 [label="DemHomeOwner <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"];
# 2827 -> 2829;
# 2830 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 2829 -> 2830;
# 2831 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2829 -> 2831;
# 2832 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2826 -> 2832;
# 2833 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2825 -> 2833;
# 2834 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2824 -> 2834;
# 2835 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 2815 -> 2835;
# 2836 [label="GiftAvgLast <= 12.5\ngini = 0.495\nsamples = 183\nvalue = [101, 82]"];
# 2812 -> 2836;
# 2837 [label="DemMedHomeValue <= 117750.0\ngini = 0.458\nsamples = 90\nvalue = [58, 32]"];
# 2836 -> 2837;
# 2838 [label="DemAge <= 82.5\ngini = 0.417\nsamples = 71\nvalue = [50, 21]"];
# 2837 -> 2838;
# 2839 [label="GiftAvgLast <= 7.5\ngini = 0.382\nsamples = 66\nvalue = [49, 17]"];
# 2838 -> 2839;
# 2840 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 2839 -> 2840;
# 2841 [label="GiftAvg36 <= 9.245\ngini = 0.359\nsamples = 64\nvalue = [49, 15]"];
# 2839 -> 2841;
# 2842 [label="DemCluster_25 <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]"];
# 2841 -> 2842;
# 2843 [label="gini = 0.0\nsamples = 19\nvalue = [19, 0]"];
# 2842 -> 2843;
# 2844 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2842 -> 2844;
# 2845 [label="GiftAvg36 <= 9.7\ngini = 0.434\nsamples = 44\nvalue = [30, 14]"];
# 2841 -> 2845;
# 2846 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 2845 -> 2846;
# 2847 [label="GiftCntAll <= 18.5\ngini = 0.375\nsamples = 40\nvalue = [30, 10]"];
# 2845 -> 2847;
# 2848 [label="DemCluster_20 <= 0.5\ngini = 0.159\nsamples = 23\nvalue = [21, 2]"];
# 2847 -> 2848;
# 2849 [label="DemCluster_18 <= 0.5\ngini = 0.087\nsamples = 22\nvalue = [21, 1]"];
# 2848 -> 2849;
# 2850 [label="gini = 0.0\nsamples = 21\nvalue = [21, 0]"];
# 2849 -> 2850;
# 2851 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2849 -> 2851;
# 2852 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2848 -> 2852;
# 2853 [label="DemAge <= 72.5\ngini = 0.498\nsamples = 17\nvalue = [9, 8]"];
# 2847 -> 2853;
# 2854 [label="DemPctVeterans <= 38.0\ngini = 0.473\nsamples = 13\nvalue = [5, 8]"];
# 2853 -> 2854;
# 2855 [label="GiftCnt36 <= 5.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]"];
# 2854 -> 2855;
# 2856 [label="PromCntCardAll <= 33.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"];
# 2855 -> 2856;
# 2857 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 2856 -> 2857;
# 2858 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2856 -> 2858;
# 2859 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 2855 -> 2859;
# 2860 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"];
# 2854 -> 2860;
# 2861 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 2853 -> 2861;
# 2862 [label="PromCntCard36 <= 16.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"];
# 2838 -> 2862;
# 2863 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"];
# 2862 -> 2863;
# 2864 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2862 -> 2864;
# 2865 [label="DemGender_M <= 0.5\ngini = 0.488\nsamples = 19\nvalue = [8, 11]"];
# 2837 -> 2865;
# 2866 [label="DemAge <= 67.0\ngini = 0.298\nsamples = 11\nvalue = [2, 9]"];
# 2865 -> 2866;
# 2867 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]"];
# 2866 -> 2867;
# 2868 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 2866 -> 2868;
# 2869 [label="GiftAvgAll <= 6.25\ngini = 0.375\nsamples = 8\nvalue = [6, 2]"];
# 2865 -> 2869;
# 2870 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2869 -> 2870;
# 2871 [label="DemMedIncome <= 95462.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"];
# 2869 -> 2871;
# 2872 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"];
# 2871 -> 2872;
# 2873 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2871 -> 2873;
# 2874 [label="GiftAvgCard36 <= 18.96\ngini = 0.497\nsamples = 93\nvalue = [43, 50]"];
# 2836 -> 2874;
# 2875 [label="GiftCnt36 <= 3.5\ngini = 0.46\nsamples = 64\nvalue = [23, 41]"];
# 2874 -> 2875;
# 2876 [label="PromCnt12 <= 12.5\ngini = 0.491\nsamples = 23\nvalue = [13, 10]"];
# 2875 -> 2876;
# 2877 [label="PromCntAll <= 26.0\ngini = 0.469\nsamples = 16\nvalue = [6, 10]"];
# 2876 -> 2877;
# 2878 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 2877 -> 2878;
# 2879 [label="DemCluster_38 <= 0.5\ngini = 0.408\nsamples = 14\nvalue = [4, 10]"];
# 2877 -> 2879;
# 2880 [label="DemCluster_5 <= 0.5\ngini = 0.355\nsamples = 13\nvalue = [3, 10]"];
# 2879 -> 2880;
# 2881 [label="PromCnt36 <= 33.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]"];
# 2880 -> 2881;
# 2882 [label="DemCluster_49 <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]"];
# 2881 -> 2882;
# 2883 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]"];
# 2882 -> 2883;
# 2884 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2882 -> 2884;
# 2885 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2881 -> 2885;
# 2886 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2880 -> 2886;
# 2887 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2879 -> 2887;
# 2888 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]"];
# 2876 -> 2888;
# 2889 [label="DemAge <= 33.5\ngini = 0.369\nsamples = 41\nvalue = [10, 31]"];
# 2875 -> 2889;
# 2890 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"];
# 2889 -> 2890;
# 2891 [label="PromCnt36 <= 42.5\ngini = 0.301\nsamples = 38\nvalue = [7, 31]"];
# 2889 -> 2891;
# 2892 [label="DemMedHomeValue <= 75300.0\ngini = 0.239\nsamples = 36\nvalue = [5, 31]"];
# 2891 -> 2892;
# 2893 [label="gini = 0.0\nsamples = 19\nvalue = [0, 19]"];
# 2892 -> 2893;
# 2894 [label="DemMedHomeValue <= 92200.0\ngini = 0.415\nsamples = 17\nvalue = [5, 12]"];
# 2892 -> 2894;
# 2895 [label="GiftCntCardAll <= 14.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]"];
# 2894 -> 2895;
# 2896 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 2895 -> 2896;
# 2897 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 2895 -> 2897;
# 2898 [label="GiftAvg36 <= 10.875\ngini = 0.165\nsamples = 11\nvalue = [1, 10]"];
# 2894 -> 2898;
# 2899 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2898 -> 2899;
# 2900 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]"];
# 2898 -> 2900;
# 2901 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 2891 -> 2901;
# 2902 [label="GiftAvgAll <= 23.175\ngini = 0.428\nsamples = 29\nvalue = [20, 9]"];
# 2874 -> 2902;
# 2903 [label="DemPctVeterans <= 8.0\ngini = 0.287\nsamples = 23\nvalue = [19, 4]"];
# 2902 -> 2903;
# 2904 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2903 -> 2904;
# 2905 [label="DemAge <= 28.5\ngini = 0.236\nsamples = 22\nvalue = [19, 3]"];
# 2903 -> 2905;
# 2906 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2905 -> 2906;
# 2907 [label="DemMedIncome <= 45497.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]"];
# 2905 -> 2907;
# 2908 [label="DemMedHomeValue <= 63250.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]"];
# 2907 -> 2908;
# 2909 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 2908 -> 2909;
# 2910 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 2908 -> 2910;
# 2911 [label="gini = 0.0\nsamples = 15\nvalue = [15, 0]"];
# 2907 -> 2911;
# 2912 [label="DemAge <= 61.075\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"];
# 2902 -> 2912;
# 2913 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2912 -> 2913;
# 2914 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"];
# 2912 -> 2914;
# 2915 [label="GiftTimeLast <= 23.0\ngini = 0.26\nsamples = 13\nvalue = [11, 2]"];
# 2625 -> 2915;
# 2916 [label="DemPctVeterans <= 21.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]"];
# 2915 -> 2916;
# 2917 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2916 -> 2917;
# 2918 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]"];
# 2916 -> 2918;
# 2919 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2915 -> 2919;
# 2920 [label="PromCnt12 <= 10.5\ngini = 0.456\nsamples = 145\nvalue = [51, 94]"];
# 2276 -> 2920;
# 2921 [label="DemPctVeterans <= 30.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]"];
# 2920 -> 2921;
# 2922 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 2921 -> 2922;
# 2923 [label="GiftAvgAll <= 12.22\ngini = 0.48\nsamples = 5\nvalue = [2, 3]"];
# 2921 -> 2923;
# 2924 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"];
# 2923 -> 2924;
# 2925 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 2923 -> 2925;
# 2926 [label="PromCnt12 <= 24.0\ngini = 0.439\nsamples = 135\nvalue = [44, 91]"];
# 2920 -> 2926;
# 2927 [label="DemMedHomeValue <= 310800.0\ngini = 0.428\nsamples = 132\nvalue = [41, 91]"];
# 2926 -> 2927;
# 2928 [label="GiftCnt36 <= 6.5\ngini = 0.331\nsamples = 62\nvalue = [13, 49]"];
# 2927 -> 2928;
# 2929 [label="GiftTimeFirst <= 56.5\ngini = 0.266\nsamples = 57\nvalue = [9, 48]"];
# 2928 -> 2929;
# 2930 [label="PromCntAll <= 35.5\ngini = 0.455\nsamples = 20\nvalue = [7, 13]"];
# 2929 -> 2930;
# 2931 [label="DemMedIncome <= 53060.729\ngini = 0.32\nsamples = 15\nvalue = [3, 12]"];
# 2930 -> 2931;
# 2932 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 2931 -> 2932;
# 2933 [label="DemCluster_13 <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]"];
# 2931 -> 2933;
# 2934 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]"];
# 2933 -> 2934;
# 2935 [label="PromCnt12 <= 12.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 2933 -> 2935;
# 2936 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2935 -> 2936;
# 2937 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2935 -> 2937;
# 2938 [label="DemAge <= 67.075\ngini = 0.32\nsamples = 5\nvalue = [4, 1]"];
# 2930 -> 2938;
# 2939 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 2938 -> 2939;
# 2940 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2938 -> 2940;
# 2941 [label="DemCluster_15 <= 0.5\ngini = 0.102\nsamples = 37\nvalue = [2, 35]"];
# 2929 -> 2941;
# 2942 [label="DemCluster_11 <= 0.5\ngini = 0.054\nsamples = 36\nvalue = [1, 35]"];
# 2941 -> 2942;
# 2943 [label="gini = 0.0\nsamples = 34\nvalue = [0, 34]"];
# 2942 -> 2943;
# 2944 [label="DemPctVeterans <= 25.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 2942 -> 2944;
# 2945 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2944 -> 2945;
# 2946 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2944 -> 2946;
# 2947 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2941 -> 2947;
# 2948 [label="DemPctVeterans <= 12.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]"];
# 2928 -> 2948;
# 2949 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2948 -> 2949;
# 2950 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 2948 -> 2950;
# 2951 [label="GiftCntAll <= 25.0\ngini = 0.48\nsamples = 70\nvalue = [28, 42]"];
# 2927 -> 2951;
# 2952 [label="GiftTimeFirst <= 55.0\ngini = 0.494\nsamples = 63\nvalue = [28, 35]"];
# 2951 -> 2952;
# 2953 [label="PromCntAll <= 25.5\ngini = 0.375\nsamples = 28\nvalue = [7, 21]"];
# 2952 -> 2953;
# 2954 [label="DemMedIncome <= 89757.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]"];
# 2953 -> 2954;
# 2955 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"];
# 2954 -> 2955;
# 2956 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 2954 -> 2956;
# 2957 [label="GiftCntAll <= 17.0\ngini = 0.236\nsamples = 22\nvalue = [3, 19]"];
# 2953 -> 2957;
# 2958 [label="DemMedIncome <= 115767.5\ngini = 0.172\nsamples = 21\nvalue = [2, 19]"];
# 2957 -> 2958;
# 2959 [label="DemCluster_11 <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [1, 19]"];
# 2958 -> 2959;
# 2960 [label="gini = 0.0\nsamples = 18\nvalue = [0, 18]"];
# 2959 -> 2960;
# 2961 [label="GiftAvg36 <= 17.665\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"];
# 2959 -> 2961;
# 2962 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2961 -> 2962;
# 2963 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2961 -> 2963;
# 2964 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2958 -> 2964;
# 2965 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"];
# 2957 -> 2965;
# 2966 [label="DemMedHomeValue <= 375850.0\ngini = 0.48\nsamples = 35\nvalue = [21, 14]"];
# 2952 -> 2966;
# 2967 [label="GiftAvgAll <= 7.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]"];
# 2966 -> 2967;
# 2968 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 2967 -> 2968;
# 2969 [label="gini = 0.0\nsamples = 12\nvalue = [12, 0]"];
# 2967 -> 2969;
# 2970 [label="PromCnt12 <= 13.5\ngini = 0.49\nsamples = 21\nvalue = [9, 12]"];
# 2966 -> 2970;
# 2971 [label="PromCntAll <= 49.0\ngini = 0.408\nsamples = 14\nvalue = [4, 10]"];
# 2970 -> 2971;
# 2972 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 2971 -> 2972;
# 2973 [label="GiftAvgCard36 <= 12.25\ngini = 0.278\nsamples = 12\nvalue = [2, 10]"];
# 2971 -> 2973;
# 2974 [label="GiftCntCardAll <= 7.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"];
# 2973 -> 2974;
# 2975 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"];
# 2974 -> 2975;
# 2976 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"];
# 2974 -> 2976;
# 2977 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]"];
# 2973 -> 2977;
# 2978 [label="GiftCntCardAll <= 10.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]"];
# 2970 -> 2978;
# 2979 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"];
# 2978 -> 2979;
# 2980 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"];
# 2978 -> 2980;
# 2981 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]"];
# 2951 -> 2981;
# 2982 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"];
# 2926 -> 2982;
# }
